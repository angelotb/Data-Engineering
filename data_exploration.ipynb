# %%
import pandas as pd

df =pd.read_csv('red_30_tech_us_sales.csv')

print(df.head())
# Out:
#       EmpID   OrderNum  OrderDate  OrderType  Quantity     Price   Discount   \
# 0  900015476   1100948   9/3/2017     Retail         1    $44.95          0
# 1  900015476   1101096  9/24/2017  Wholesale        10     $4.99      $1.00
# 2  900015476   1101138  10/1/2017  Wholesale         4   $250.00     $50.00
# 3  900015476   1101158  10/3/2017     Retail         1   $250.00          0
# 4  900015476   1101181  10/9/2017     Retail         1    $13.99          0
#
#    Order Total
# 0       $44.95
# 1       $48.90
# 2      $950.00
# 3      $250.00
# 4       $13.99

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4976 entries, 0 to 4975
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   EmpID          4976 non-null   int64
#  1   OrderNum       4976 non-null   int64
#  2   OrderDate      4976 non-null   object
#  3   OrderType      4976 non-null   object
#  4   Quantity       4976 non-null   int64
#  5    Price         4976 non-null   object
#  6    Discount      4976 non-null   object
#  7    Order Total   4976 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 311.1+ KB

# %%
df['OrderNum']
# Out:
# 0       1100948
# 1       1101096
# 2       1101138
# 3       1101158
# 4       1101181
#          ...
# 4971    1105360
# 4972    1105451
# 4973    1105501
# 4974    1105748
# 4975    1105834
# Name: OrderNum, Length: 4976, dtype: int64

# %%
df[df['Quantity']> 10]
# Out:
#          EmpID   OrderNum   OrderDate  OrderType  Quantity     Price   \
# 7     900015476   1101495  11/22/2017  Wholesale        13   $899.00
# 17    900015476   1102227    3/9/2018  Wholesale        15    $13.99
# 29    900015476   1103219   7/27/2018  Wholesale        53    $69.00
# 38    900015476   1103799  10/18/2018  Wholesale        78    $44.95
# 51    900015476   1104837   3/23/2019  Wholesale        13    $89.00
# ...         ...       ...         ...        ...       ...        ...
# 4969  900011189   1105229   5/21/2019  Wholesale        83    $32.95
# 4972  900011189   1105451   6/20/2019  Wholesale        69   $450.00
# 4973  900011189   1105501   6/28/2019  Wholesale        11    $28.99
# 4974  900011189   1105748    8/7/2019  Wholesale        11   $119.00
# 4975  900011189   1105834   8/18/2019  Wholesale        67    $42.99
#
#       Discount   Order Total
# 7      $179.80    $11,507.20
# 17       $2.80       $207.05
# 29      $13.80     $3,643.20
# ...

# %%
df[(df['Quantity']>10) & (df['OrderType']!= "Wholesale")]
# Out:
#          EmpID   OrderNum   OrderDate OrderType  Quantity     Price   \
# 119   900019884   1104570   2/14/2019    Retail        60   $450.00
# 210   900018190   1101368   11/2/2017    Retail        48    $49.00
# 549   900010405   1105819   8/16/2019    Retail        16     $8.99
# 574   900014598   1101646  12/12/2017    Retail        12   $179.00
# 598   900014598   1102372    4/1/2018    Retail        13    $19.99
# 645   900014598   1103986  11/16/2018    Retail        87   $899.00
# 653   900014598   1104229  12/21/2018    Retail        41    $29.99
# 748   900014032   1103375   8/17/2018    Retail        46    $37.99
# 788   900014032   1105860   8/22/2019    Retail        68    $49.95
# 1021  900012972   1104668   2/27/2019    Retail        12   $189.00
# 1071  900012260   1102471   4/15/2018    Retail        31    $19.50
# 1135  900019833   1102082   2/16/2018    Retail       109    $23.99
# 1218  900014980   1100983    9/8/2017    Retail        24    $23.99
# ...

# %%
df.dtypes
# Out:
# EmpID             int64
# OrderNum          int64
# OrderDate        object
# OrderType        object
# Quantity          int64
#  Price           object
#  Discount        object
#  Order Total     object
# dtype: object

# %%
unique_ids = pd.Series(df['EmpID '].unique())

print(unique_ids)
# Out:
# 0     900015476
# 1     900019884
# 2     900012297
# 3     900018190
# 4     900010405
# 5     900014598
# 6     900014032
# 7     900012180
# 8     900012972
# 9     900012260
# 10    900019833
# 11    900014980
# 12    900013598
# 13    900018996
# 14    900016416
# 15    900012326
# 16    900012483
# 17    900010875
# 18    900010836
# 19    900018661
# 20    900012723
# 21    900019311
# 22    900018689
# 23    900019978
# 24    900015938
# 25    900010430
# 26    900016297
# 27    900015082
# 28    900017930
# 29    900016088
# 30    900013626
# 31    900013387
# 32    900017044
# 33    900012258
# 34    900015673
# 35    900011056
# 36    900019250
# 37    900016392
# 38    900013587
# 39    900016602
# 40    900011678
# 41    900018460
# 42    900010813
# 43    900011189
# dtype: int64
