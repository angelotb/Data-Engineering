# %%
import pandas as pd 

def get_data_from_google_sheet(sheet_url):
    csv_url = sheet_url.split("/edit")[0] + "/export?format=csv&gid=0"

    try:
        df = pd.read_csv(csv_url)

        expected_columns = ['state_name', 'state_code', 'state_timezone']

        if all(col in df.columns for col in expected_columns):
            df = df[expected_columns]
        else:
            print("Expected columns are not found in the DataFrame")
            return None
        
        return df
    except Exception as e:
        print(f"Error fetching data: {e}")
        return None

sheet_url = "https://docs.google.com/spreadsheets/d/1I31B5NN7tFYntmATiEE_PiQhZ47DsAXetiDrVsVehfM/edit?pli=1&gid=0#gid=0"
df = get_data_from_google_sheet(sheet_url)

if df is not None:
    print(df.head())
# Out:
#    state_name state_code                                 state_timezone
# 0     Alabama         AL                              Central Time (CT)
# 1      Alaska         AK  Alaska Time (AKT), Hawaii-Aleutian Time (HAT)
# 2     Arizona         AZ                            Mountain Time (MT)*
# 3    Arkansas         AR                              Central Time (CT)
# 4  California         CA                              Pacific Time (PT)

# %%
df['state_timezone'] = df['state_timezone'].str.replace('*', '', regex=False)

df.head(49)
# Out:
#         state_name state_code                                 state_timezone
# 0          Alabama         AL                              Central Time (CT)
# 1           Alaska         AK  Alaska Time (AKT), Hawaii-Aleutian Time (HAT)
# 2          Arizona         AZ                             Mountain Time (MT)
# 3         Arkansas         AR                              Central Time (CT)
# 4       California         CA                              Pacific Time (PT)
# 5         Colorado         CO                             Mountain Time (MT)
# 6      Connecticut         CT                              Eastern Time (ET)
# 7         Delaware         DE                              Eastern Time (ET)
# 8          Florida         FL           Eastern Time (ET), Central Time (CT)
# 9          Georgia         GA                              Eastern Time (ET)
# 10          Hawaii         HI                     Hawaii-Aleutian Time (HAT)
# 11           Idaho         ID          Mountain Time (MT), Pacific Time (PT)
# 12        Illinois         IL                              Central Time (CT)
# 13         Indiana         IN           Eastern Time (ET), Central Time (CT)
# 14            Iowa         IA                              Central Time (CT)
# 15          Kansas         KS          Central Time (CT), Mountain Time (MT)
# 16        Kentucky         KY           Eastern Time (ET), Central Time (CT)
# 17       Louisiana         LA                              Central Time (CT)
# 18           Maine         ME                              Eastern Time (ET)
# 19        Maryland         MD                              Eastern Time (ET)
# 20   Massachusetts         MA                              Eastern Time (ET)
# 21        Michigan         MI           Eastern Time (ET), Central Time (CT)
# 22       Minnesota         MN                              Central Time (CT)
# 23     Mississippi         MS                              Central Time (CT)
# 24        Missouri         MO                              Central Time (CT)
# 25         Montana         MT                             Mountain Time (MT)
# 26        Nebraska         NE          Central Time (CT), Mountain Time (MT)
# 27          Nevada         NV          Pacific Time (PT), Mountain Time (MT)
# 28   New Hampshire         NH                              Eastern Time (ET)
# 29      New Jersey         NJ                              Eastern Time (ET)
# 30      New Mexico         NM                             Mountain Time (MT)
# 31        New York         NY                              Eastern Time (ET)
# 32  North Carolina         NC                              Eastern Time (ET)
# 33    North Dakota         ND          Central Time (CT), Mountain Time (MT)
# 34            Ohio         OH                              Eastern Time (ET)
# 35        Oklahoma         OK                              Central Time (CT)
# 36          Oregon         OR          Pacific Time (PT), Mountain Time (MT)
# 37    Pennsylvania         PA                              Eastern Time (ET)
# 38    Rhode Island         RI                              Eastern Time (ET)
# 39  South Carolina         SC                              Eastern Time (ET)
# 40    South Dakota         SD          Central Time (CT), Mountain Time (MT)
# 41       Tennessee         TN           Eastern Time (ET), Central Time (CT)
# 42           Texas         TX          Central Time (CT), Mountain Time (MT)
# 43            Utah         UT                             Mountain Time (MT)
# 44         Vermont         VT                              Eastern Time (ET)
# 45        Virginia         VA                              Eastern Time (ET)
# 46      Washington         WA                              Pacific Time (PT)
# 47   West Virginia         WV                              Eastern Time (ET)
# 48       Wisconsin         WI                              Central Time (CT)

# %%
import sqlite3

conn = sqlite3.connect('database.db')
table_name = 'us_state_codes'
identifier_colum = 'state_name'

try:
    existing_df = pd.read_sql_query(f"SELECT *FROM [table_name]", conn)

    merged_df = pd.merge(existing_df, df, on=identifier_colum, how='outer', suffixes=('_old', '_new'))
    
    update_mask = merged_df[identifier_colum].isin(existing_df[identifier_colum]) & merged_df[identifier_colum].isin(df[identifier_colum])

    for col in df.columns:
        if col != identifier_colum and f'{col}_new' in merged_df.colums:
            merged_df.loc[update_mask, col] = merged_df[f'[col]_new']

    final_df = merged_df[df.columns]

except pd.io.sql.DatabaseError:
    final_df = df

final_df.to_sql(table_name, conn, if_exists='replace', index=False)

print(f"Data in table '{table_name}' has been merged/updated")

conn.close()
# Out:
# Data in table 'us_state_codes' has been merged/updated
